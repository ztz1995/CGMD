# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle as pkl
import os, sys
sys.path.append("/home/centos/CGMD/")
# from pyMD import analysis as ans
from matplotlib.font_manager import FontProperties
from matplotlib import rcParams
config = {
    "mathtext.fontset":"stix",
    "font.family":'STIXGeneral',
}
rcParams.update(config)
from pyMD import ibi
# Out:
# using CGU

# %%
fp1 = "../../data/20200722_lr=0.05_1blk_50_cgu_ex_hard/record/"
r1 = ibi.Record(fp1, restart=True)
param1 = r1.get_param(353, 1)

# %%
param1["non_bond"][('TO(2)', 'TO(2)')]
# Out:
# array([4.44636403e+22, 8.68430475e+19, 2.25898696e+18, ...,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00])

# %%
plt.rcParams['mathtext.fontset'] = 'stix'
plt.rcParams['font.family'] = 'STIXGeneral'
begin = 300
dpi = 200
fontsize = 12
plt.figure(figsize=(4,3), dpi=dpi)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.xlabel(r"Distance $\mathbf{[}\mathrm{\AA}\mathbf{]}$", fontsize=fontsize+4)
plt.ylabel(r"Potential $\mathbf{[}$kcal/mol$\mathbf{]}$", fontsize=fontsize+4)

plt.plot(ibi.IBI.cal_points["non_bond"][begin:], param1["non_bond"][('TO(2)', 'TO(2)')][begin:])
