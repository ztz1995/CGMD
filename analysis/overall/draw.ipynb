# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle as pkl
import os, sys
sys.path.append("/home/centos/CGMD/")
# from pyMD import analysis as ans

from matplotlib.font_manager import FontProperties
from matplotlib import rcParams
config = {
    "mathtext.fontset":"stix",
    "font.family":'STIXGeneral',
    "font.serif":['SimSun'],
}
rcParams.update(config)
SimSun = FontProperties(fname='/home/centos/anaconda3/envs/md/lib/python3.7/site-packages/matplotlib/mpl-data/fonts/ttf/SimSun.ttf')

# %%
import pandas as pd
labels = ["AA", "CGU", "CG"]
names = ["aa2cg", "cgu2cg", "cg"]
colors = ["tab:red", "tab:blue", "0.1"]

dpi = 400
fontsize = 12
plt.figure(dpi=dpi, figsize=(4,3))

for i in range(3):
    # with open("data/EndToEnd_%s" % labels[i].lower(), "rb") as file:
    with open("data/gyration_%s.pkl" % labels[i].lower(), "rb") as file:
        dists = pkl.load(file)
    # values, bins = np.histogram(dists, bins=40, range=[0, 80], density=True)
    values, bins = np.histogram(dists, bins=40, range=[5, 25], density=True)
    x = bins[:-1] + (bins[1] - bins[0])/2
    plt.plot(x, values, label=labels[i], color=colors[i], zorder=3-i)


fontdict = {"fontproperties":SimSun, "fontsize":fontsize+4}
plt.xlabel(r"回转半径 $\mathbf{[} \mathrm{\AA} \mathbf{]}$", fontdict=fontdict)
plt.ylabel(r"概率密度", fontdict=fontdict)
plt.legend(loc="upper left", frameon=False, fontsize=fontsize)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.tight_layout()
plt.savefig("2 e2e_1.jpg", dpi=dpi)
plt.show()

# %%
import pandas as pd
labels = ["AA", "CGU", "CG"]
names = ["aa2cg", "cgu2cg", "cg"]
colors = ["tab:red", "tab:blue", "0.1"]

dpi = 400
fontsize = 12
plt.figure(dpi=dpi, figsize=(4,3))

for i in range(3):
    with open("data/EndToEnd_%s" % labels[i].lower(), "rb") as file:
    # with open("data/gyration_%s.pkl" % labels[i].lower(), "rb") as file:
        dists = pkl.load(file)
    values, bins = np.histogram(dists, bins=40, range=[0, 80], density=True)
    # values, bins = np.histogram(dists, bins=40, range=[5, 25], density=True)
    x = bins[:-1] + (bins[1] - bins[0])/2
    plt.plot(x, values, label=labels[i], color=colors[i], zorder=3-i)


fontdict = {"fontproperties":SimSun, "fontsize":fontsize+4}
plt.xlabel(r"末端距 $\mathbf{[} \mathrm{\AA} \mathbf{]}$", fontdict=fontdict)
plt.ylabel(r"概率密度", fontdict=fontdict)
plt.legend(loc="upper left", frameon=False, fontsize=fontsize)
plt.xticks(fontsize=fontsize)
plt.yticks(fontsize=fontsize)
plt.tight_layout()
plt.savefig("2 e2e.jpg", dpi=dpi)
plt.show()
