# %%
import os, sys
sys.path.append("/home/centos/CGMD/")
import pyMD.functions as func
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(2., 10., 0.1)
# p = [2.23231, 8.38255, 0.00000, 0.00000, 5.21581]
p = [2.09719, 7.68118, 0.00000, 0.00000, 5.28250]
y = func.fene_expand(x, p[0], p[-1], p[1])
plt.plot(x, y)

# %%
popt = func.fit_bond(x, y, "fene/expand", p0=[p[0], p[-1], p[1]], k=4.0)
print(popt)
plt.plot(x, y)
plt.plot(x, func.fene_expand(x, *popt))
# Out:
# [ 2.3433215   5.24923832 20.0735    ]

# %%
p1 = [ 1.09719,   5.28250, 7.68118    ]
plt.plot(x, y)
plt.plot(x, func.fene_expand(x, *p1))
