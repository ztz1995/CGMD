# %%
import os, sys
sys.path.append("/home/centos/CGMD/")
from pyMD.file_parser import LmpParser
import os
# Out:
# using CGU

# %%
fp1 = "/home/centos/ztz/dpd_hybrid_large/dpd-200_cgu/data.8blk_200"
cg_atom3d = LmpParser.load_data_file(fp1, map_dict={"Me":"c3"})
cg_atom3d.renew_coordinate_file("/home/centos/ztz/dpd_hybrid_large/dpd-200_cgu/init/trj/init.8blk_200.lammpstrj.200000")
# Out:
# ['Es', 'c3', 'Ph', 'TO(1)', 'TO(2)', 'c1', 'h1', 'n1', 'o1']
# {}

# %%
cg_atom3d.cgu_to_fgh()
fp2 = "/home/centos/ztz/dpd_hybrid_large/dpd-200_fg/"
os.makedirs(fp2, exist_ok=True)
LmpParser.create_data_file(cg_atom3d, fp2 + "data.8blk_200", q=False, improper=True)

# %%
fp1 = "/home/centos/ztz/dpd_hybrid_large_1/dpd-200_cgu/data.8blk_200"
cg_atom3d = LmpParser.load_data_file(fp1, map_dict={"Me":"c3"})
cg_atom3d.set_type_define("fg")
cg_atom3d.renew_coordinate_file("/home/centos/ztz/dpd_hybrid_large_1/dpd-200_cgu/init/trj/init.8blk_200.lammpstrj.1130000")
cg_atom3d.cgu_to_fgh()
fp2 = "/home/centos/ztz/dpd_hybrid_large_1/dpd-200_fg/"
os.makedirs(fp2, exist_ok=True)
LmpParser.create_data_file(cg_atom3d, fp2 + "data.8blk_200", q=False, improper=True)

# %%
fp1 = "/home/centos/ztz/glass_trainsition/hard/dpd_cgu/data.1blk_400"
cg_atom3d = LmpParser.load_data_file(fp1, map_dict={"Me":"c3"})
cg_atom3d.set_type_define("fg")
cg_atom3d.renew_coordinate_file("/home/centos/ztz/glass_trainsition/hard/dpd_cgu/init/trj/init.1blk_400.lammpstrj.1130000")
cg_atom3d.cgu_to_fgh()
fp2 = "/home/centos/ztz/glass_trainsition/hard/dpd_fg/"
os.makedirs(fp2, exist_ok=True)
LmpParser.create_data_file(cg_atom3d, fp2 + "data.1blk_400", q=False, improper=True)
# Out:
# ['c3', 'Ph', 'c1', 'h1', 'n1', 'o1']
# use new fg
# use new fg
# use new fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# tail fg
# ...

# %%
fp1 = "/home/centos/ztz2/MC/pmf/intra_0/data.pmf_intra_0"
cg_atom3d = LmpParser.load_data_file(fp1, map_dict={"Me":"c3"})
cg_atom3d.set_type_define("fg")
cg_atom3d.renew_coordinate_file("/home/centos/ztz2/MC/pmf/intra_0/init/trj/init.pmf_intra_0.lammpstrj.1000000")
cg_atom3d.cgu_to_fgh()
fp2 = "/home/centos/ztz2/MC/pmf_fg/intra_0/data.pmf_intra_0"
os.makedirs(fp2, exist_ok=True)
LmpParser.create_data_file(cg_atom3d, fp2 + "data.1blk_400", q=False, improper=True)
